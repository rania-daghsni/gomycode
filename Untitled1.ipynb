# %% [markdown]
# <a href="https://colab.research.google.com/github/rania-daghsni/gomycode/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import*
x=int(input("write your guess"))
y=random.randint(1,100)
while x!=y:
  if(x<y):
    print("your guess is very high")
  elif(x>y):
    print("your guess is very low")
  else:
    print("correct!")
# Out:
# write your guess15
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-036a7c9155f7> in <cell line: 3>()
#       1 from random import*
#       2 x=int(input("write your guess"))
# ----> 3 y=random.randint(1,100)
#       4 while x!=y:
#       5   if(x<y):
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'randint'
