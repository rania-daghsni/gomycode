# %% [markdown]
# <a href="https://colab.research.google.com/github/rania-daghsni/gomycode/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import request
import string
import b from beautifulsoup
enter_input=input("search :")
u_i=string.capwords(enter_input)
word="_".join(lists)
url="https://en.wikipedia.org/wiki/"+word
def wiki(url):
  url_open=requests.get(url)
  soup=beautifulsoup( url_open.content,"html.parser")
  detail=soup('table',{'class': 'infobox'})
