# %% [markdown]
# <a href="https://colab.research.google.com/github/rania-daghsni/gomycode/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l=[2,3,6]
multp=1
for elem in l:
  multp=multp*elem
print(multp)
# Out:
# 36

# %%
l=[(2,5),(1,2),(4,4),(2,3),(2,1)]
ll=len(l)
aux={}
for i in range(0,ll):
  aux[l[i][0]]=l[i][1]
  print(aux)
# Out:
# {2: 5}
# {2: 5, 1: 2}
# {2: 5, 1: 2, 4: 4}
# {2: 3, 1: 2, 4: 4}
# {2: 1, 1: 2, 4: 4}

# %%
d1={}

# %%
"""question 4"""
n=int(input("donner n"))
dict={}
for i in range(1,n+1):
  dict[i]=i*i
print(dict)
# Out:
# donner n7
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49}

# %%
l= [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
for elem in l:
  l.sort(reverse=True)
print(l)
# Out:
# [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
# [('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20')]

# %%
l = [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
ll = len(l)
aux = {}
for i in range(ll):
  #aux.add(int(l[i][1][3:6]))
  aux[l[i][0]] = int(l[i][1][3:6])
print(aux)
aux2 = sorted(aux.values())
print(aux2)
aux3 = l[0]
l[1] =l[1]
l[0] = aux3
print(l)
# Out:
# {'item1': 20, 'item2': 10, 'item3': 5}
# [5, 10, 20]
# [20, 10, 5]
# [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]

# %%
"""question 6"""
set={1,2,5}
while set!={}

set.add(8)
print(set)
set.remove(1)
print(set)
# Out:
# {8, 1, 2, 5}
# {8, 2, 5}

# %%
d={'r':1,'t':6,'y':5}
d.values()
d2=sorted(d.values())
print(d2)
l2=[]
# Out:
# [1, 5, 6]
