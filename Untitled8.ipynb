# %% [markdown]
# <a href="https://colab.research.google.com/github/rania-daghsni/gomycode/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
n=int(input("enter students number"))
s=int(input("enter subjects number"))
array=np.array(n,s)
print(array)
m=int(input("enter student's mark"))


totalmarks=sum(array)
p=(totalmarks / (s * 100)) * 100
if p>90:
  print(grade=A+)
elif p>80:
  print(grade=A)
elif p>70:
  print(grade=B+)
elif p>60:
  print(grade=B)
elif p>50:
  print(grade=C)
else:
  print(grade=F)
# Out:
# enter students number2
# enter subjects number1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9f3ef1e114c2> in <cell line: 4>()
#       2 n=int(input("enter students number"))
#       3 s=int(input("enter subjects number"))
# ----> 4 array=np.array(n,s=1)
#       5 print(array)
#       6 m=float(input("enter student's mark"))
#
# TypeError: array() got an unexpected keyword argument 's'
